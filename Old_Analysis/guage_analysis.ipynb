# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("Data/Daily_Max_Vals.csv")

# %%
dates = df['date'].to_numpy()
year = []

for date in dates:
    year.append(date[0:4])

df["year"] = year

# %%
df["year"].unique() = df["year"].unique()

# %%
yearly_gauge = {}

for year in years:
	temp_df = df[df['year'] == year]
	yearly_gauge[year] = round(temp_df["gauge"].mean(), 2)

yearly_gauge = DataFrame({'Year': yearly_gauge.keys(), 'Mean Gauge': yearly_gauge.values()})
yearly_gauge
# Out:
#     Year  Mean Gauge
# 0   2007        3.13
# 1   2008        3.37
# 2   2009        3.69
# 3   2010        3.37
# 4   2011        3.89
# 5   2012        3.21
# 6   2013        3.49
# 7   2014        3.54
# 8   2015        3.28
# 9   2016        3.13
# 10  2017        3.25
# 11  2018        3.87
# 12  2019        3.70
# 13  2020        3.37
# 14  2021        3.52
# 15  2022        3.33

# %%
# Setup
plt.rcParams["figure.figsize"] = (14, 8)
plt.figure(dpi=1000)
matplotlib.rc('xtick', labelsize=15) 
matplotlib.rc('ytick', labelsize=15)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
ax = sns.lineplot(x=years, y=yearly_gauge)
ax.set_xticklabels(years, rotation=30)
plt.title('Mean Annual Gauge')
# Out:
# /var/folders/9n/cydgwsgx6h32_js3qd22zk1m0000gn/T/ipykernel_3921/452233108.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(years, rotation=30)
# Text(0.5, 1.0, 'Mean Annual Gauge')
